# %%
import pandas as pd

# %%
df = pd.read_csv('ex.csv')
print(df)
# Out:
#        Component            Model                 Specs  Price_INR      Stock
# 0      Processor      AMD Ryzen 5  6 cores / 12 threads      20150  Available
# 1            SSD       NVMe 512GB   5000MB/s read speed       7000  Available
# 2  Graphics Card  NVIDIA RTX 2050             4GB GDDR6      15000    Limited
# 3            RAM        DDR5 16GB               5600MHz      18460  Available
# 4    Motherboard         MSI B550                   ATX      12500  Available
# 5   Power Supply     Corsair 650W            80+ Bronze       5200  Available

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
print(df)
# Out:
# x   NaN
# y   NaN
# z   NaN
# dtype: float64

# %%
print(df)
# Out:
# x   NaN
# y   NaN
# z   NaN
# dtype: float64

# %%
df = pd.read_csv('ex.csv')
print(df)
# Out:
#        Component            Model                 Specs  Price_INR      Stock
# 0      Processor      AMD Ryzen 5  6 cores / 12 threads      20150  Available
# 1            SSD       NVMe 512GB   5000MB/s read speed       7000  Available
# 2  Graphics Card  NVIDIA RTX 2050             4GB GDDR6      15000    Limited
# 3            RAM        DDR5 16GB               5600MHz      18460  Available
# 4    Motherboard         MSI B550                   ATX      12500  Available
# 5   Power Supply     Corsair 650W            80+ Bronze       5200  Available

# %%
myvar = pd.Series(calories, index= ["day1"])

# %% [markdown]
# # to add a index num we use ".to_string()"

# %%
df = pd.read_csv('ex.csv')
print(df.to_string())
# Out:
#        Component            Model                 Specs  Price_INR      Stock
# 0      Processor      AMD Ryzen 5  6 cores / 12 threads      20150  Available
# 1            SSD       NVMe 512GB   5000MB/s read speed       7000  Available
# 2  Graphics Card  NVIDIA RTX 2050             4GB GDDR6      15000    Limited
# 3            RAM        DDR5 16GB               5600MHz      18460  Available
# 4    Motherboard         MSI B550                   ATX      12500  Available
# 5   Power Supply     Corsair 650W            80+ Bronze       5200  Available

# %% [markdown]
# # to see total rows we use this
# ## .options.display.max_rows

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

dfJson = pd.DataFrame(data)

print(dfJson)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# # to see top values
# ## we use .head(any number)

# %%
print(dfJson.head(5))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406

# %% [markdown]
# ## use .tail( any number )

# %%
print(dfJson.tail(2))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ## to see all info of data we use info

# %%
print(dfJson.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  6 non-null      int64
#  3   Calories  6 non-null      int64
# dtypes: int64(4)
# memory usage: 240.0+ bytes
# None

# %% [markdown]
# # Pandas - Cleaning Data
#
# ## Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# * Empty cells
# * Data in wrong format
# * Wrong data
# * Duplicates

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined
